# %% [markdown]
# asteroids
# - movement
# - sprite
# - split function
# - collision with ship
# - collision with bullets
# - Limtit: 26 asteroids on screen at a time
#
# ship
# - mouse turning
# - sprite
# - click to shoot
# - bullets
# - collision with asteroids
#
# bullets
# - movement
# - sprite
# - collision with asteroids
#
# lives
# - start 3 - 5
# - every 10.000 points extra one
#
# highscore
# -
#
# gametime
