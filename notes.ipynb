# %% [markdown]
# asteroids
# - movement
# - sprite
# - split function
# - collision with ship
# - collision with bullets
#
# ship
# - mouse turning
# - click to shoot
# - bullets
#
# bullets
# - movement
#
# lives
#
# highscore
#
# gametime
